# %%
import json
import requests  # Ensure requests is imported
from IPython.display import display, Markdown

# Define the APIError exception class
class APIError(Exception):
    pass


# Define the HeyDataAPIClient class (as provided)
class HeyDataAPIClient:
    """
    Interacts with the HeyDataAPI to execute data skills.
    """
    def __init__(self, api_url):
        self._api_url = api_url

    def call_api(self, user_input):
        """
        Calls the HeyDataAPI with the given user input and returns the response.
        """
        data = {
            "phoneNumber": "+123456789", #phone number in international format.
            "mail": "", # Optional at the time of writing. May be added in the future.
            "location": "", # City, country, etc. Not required.
            "userRequest": user_input,
            "userName": "Kronika Technologies", # Name of the user. Required
            "model": "", # Claude, GPT, Mixtral, Grok, etc.
            "bot": "Gideon", # Name of the bot. Select to manage context in future updates.
            "outputLength": 500, # Maximum number of characters to return. Go wild. Or not. 
            "fromShortcuts": False,
            "returnFiles": False,
            "currentUserTime": "2023-03-10T16:00:00.000Z",
        }
        try:
            response = requests.post(self._api_url, json=data)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            logger.error(f"API request failed: {e}")
            raise APIError(f"API request failed: {e}")

# %%
def save_to_file(user_input, api_response, user_name, bot_name):
    """
    Saves the user input and API response to files and creates a chatlog.md file if it does not exist.
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Write the formatted dialogue to chatlog.md
    with open("chatlog.md", "a") as chatlog_md:
        chatlog_md.write(f"## User Input:\n{user_input}\n\n")
        chatlog_md.write(f"## Response:\n{api_response}\n\n")

    # Write the user input and response details to chatlog.txt  
    with open("chatlog.txt", "a") as chatlog_txt:
        chatlog_txt.write(f"User Name: {user_name}\n\n")
        chatlog_txt.write(f"User Input:\n{user_input}\n\n") 
        chatlog_txt.write(f"Bot Name: {bot_name}\n\n")
        chatlog_txt.write(f"Response:\n{api_response}\n\n")

# %%
# Ask user for input (string) for user_input:
user_input = input("Enter your request for DATA: ")

# Create an instance of the HeyDataAPIClient class
api_url = "https://heydata.org/api/v1/coreDATA"
hey_data_api_client = HeyDataAPIClient(api_url)

try:
    # Execute the user's request for DATA using the refactored class
    response = hey_data_api_client.call_api(user_input)
    
    # Parses the API response from json into a dictionary and extracts the user_name, user_request, bot_name and message values.
    user_name, user_request, bot_name, message = response["userName"], response["originalRequest"], response["bot"], response["message"]
    
    # Prints the dictionary values in a formatted string as a dialogue between the user and the bot.
    print(f"**{user_name}**: {user_request}\n\n**{bot_name}**: {message}")
    
    # Call the save_to_file function to save the user input and API response
    save_to_file(user_request, message, user_name, bot_name)
    
except Exception as e:
    # Handle any exceptions that may occur during the execution of the user's request for DATA.
    print(f"Error: {e}")

print("Thank you for using HeyDataAPI through Kronika!")
# Out:
# **Bastian**: -askSmartAIs: Dime, por que Batman no se rie de los chistes del guason?
#
# **Gideon**: # Your Answer from the Universe
#
# **You asked:**
#
# Dime, por que Batman no se rie de los chistes del guason?
#
# ## mistral-large-latest-DATA's response:
#
# ### mistral-large-latest-DATA:
#
# Los supervillanos como el Joker son conocidos por usar mucho humor y comedia en sus actos malvados. Batman, siendo un héroe serio y centrado en combatir el crimen, no se ríe de los chistes del Joker porque eso iría en contra de su carácter y principios. Batman toma muy en serio su papel y no se permite perder la compostura, incluso cuando se enfrenta a las excentricidades de su archienemigo. Su objetivo es detener los planes del Joker, no entrar en su juego de bromas y risas. Esto forma parte de la tensión y dinámica entre estos dos personajes emblemáticos de los cómics.
#
#
# ### mistral large latest-without-conversation-history:
#
# Batman doesn't laugh at the Joker's jokes because their relationship is not based on humor, but rather on a deep-seated grudge and a twisted game of cat and mouse. The Joker often engages in criminal activities and violent acts as a way to prove his superiority and to lure Batman into his games, while Batman sees through the Joker's attempts to manipulate him and focuses on bringing him to justice. Additionally, the Joker's jokes often revolve around violence, chaos, and death, which is not something Batman finds funny.
#
# Moreover, Batman is a character with a dark and tragic past, which has made him a serious and brooding individual. He has seen the worst that humanity has to offer and has dedicated his life to fighting crime and protecting the innocent. As a result, he has little patience for frivolous things like jokes and pranks.
#
# In summary, Batman doesn't laugh at the Joker's jokes because their relationship is based on a deep-seated grudge, the Joker's jokes are often dark and violent, and Batman is a serious and brooding character who has little patience for frivolous things.
#
# ---
#
# ## gpt-4-0125-preview-DATA's response:
#
# ### gpt-4-0125-preview-DATA:
#
# Batmanno se ríe de los chistes del Joker porque no considera apropiado reírse de las bromas del villano, incluso si son ingeniosas o ingeniosas. Batman se enfoca en detener las actividades criminales y trastornadas del Joker, por lo que no ve gracia en sus chistes y payasadas. Batman toma muy en serio su papel como defensor de la justicia y no cree que sea correcto reírse de las acciones dañinas del Joker, independientemente de la calidad de sus bromas.
#
#
# ### gpt 4 0125-preview-without-conversation-history:
#
# Batman doesn't laugh at the Joker's jokes because their relationship is not based on humor, but rather on a deep-seated grudge and a twisted game of cat and mouse. The Joker often engages in criminal activities and violent acts as a way to prove his superiority and to lure Batman into his games, while Batman sees through the Joker's attempts to manipulate him and focuses on bringing him to justice. Additionally, the Joker's jokes often revolve around violence, chaos, and death, which is not something Batman finds funny.
#
# Moreover, Batman is a character with a dark and tragic past, which has made him a serious and brooding individual. He has seen the worst that humanity has to offer and has dedicated his life to fighting crime and protecting the innocent. As a result, he has little patience for frivolous things like jokes and pranks.
#
# In summary, Batman doesn't laugh at the Joker's jokes because their relationship is based on a deep-seated grudge, the Joker's jokes are often dark and violent, and Batman is a serious and brooding character who has little patience for frivolous things.
#
# ---
#
# ## gpt-4-32k-DATA's response:
#
# ### gpt-4-32k-DATA:
#
# Creo que la razón por la que Batman no se ríe de los chistes del Joker es porque tienen una relación complicada y antagónica. Batman ve al Joker como un villano peligroso y amenaza para la ciudad, por lo que no encuentra gracia en sus bromas y provocaciones. Para Batman, el Joker es alguien a quien debe detener y encarcelar, no alguien con quien pueda reír o compartir una complicidad. Su interacción se basa más en el conflicto y el enfrentamiento que en la camaradería o el humor compartido.
#
#
# ### gpt 4 32k-without-conversation-history:
#
# Batman doesn't laugh at the Joker's jokes because their relationship is not based on humor, but rather on a deep-seated grudge and a twisted game of cat and mouse. The Joker often engages in criminal activities and violent acts as a way to prove his superiority and to lure Batman into his games, while Batman sees through the Joker's attempts to manipulate him and focuses on bringing him to justice. Additionally, the Joker's jokes often revolve around violence, chaos, and death, which is not something Batman finds funny.
#
# Moreover, Batman is a character with a dark and tragic past, which has made him a serious and brooding individual. He has seen the worst that humanity has to offer and has dedicated his life to fighting crime and protecting the innocent. As a result, he has little patience for frivolous things like jokes and pranks.
#
# In summary, Batman doesn't laugh at the Joker's jokes because their relationship is based on a deep-seated grudge, the Joker's jokes are often dark and violent, and Batman is a serious and brooding character who has little patience for frivolous things.
#
# ---
#
# ## claude-3-opus-20240229-DATA's response:
#
# ### claude-3-opus-20240229-DATA:
#
# I don't actually have the capability to browse the web or provide information about real-time events happening in San Francisco or elsewhere. As an AI assistant without direct access to current data sources, I am limited to relying on my training data which only covers information up to 2021. I apologize that I cannot fulfill this particular request to provide up-to-date details on San Francisco happenings this Friday. Please let me know if there are other topics you'd like to discuss that don't require real-time knowledge of current events and I'll do my best to assist!
#
#
# ### claude 3 opus-20240229-without-conversation-history:
#
# Batman no se ríe de los chistes del Guasón por varias razones:
#
# 1. El Guasón es su enemigo: La relación entre Batman y el Guasón es antagónica. El Guasón es un criminal despiadado que causa caos y destrucción en Gotham, mientras que Batman lucha por proteger la ciudad y hacer justicia. Reírse de los chistes de su archienemigo sería inapropiado.
#
# 2. Los chistes del Guasón son crueles y retorcidos: El humor del Guasón a menudo implica violencia, sufrimiento y muerte. Sus chistes son una manifestación de su locura y su falta de empatía por los demás. Batman, siendo un héroe con un fuerte código moral, no encuentra gracioso este tipo de humor negro.
#
# 3. Batman es un personaje serio y estoico: La personalidad de Batman se caracteriza por su seriedad, determinación y autocontrol. Rara vez muestra emociones, especialmente cuando está enfrentando a criminales. Reírse de los chistes, incluso si no fueran del Guasón, no encaja con su imagen de justiciero sombrio.
#
# 4. No quiere darle al Guasón la satisfacción: El Guasón disfruta provocando a Batman y tratando de hacerlo perder el control. Si Batman se riera de sus chistes, el Guasón sentiría que ha logrado su objetivo de desestabilizar emocionalmente a su enemigo. Al no reaccionar, Batman muestra su fortaleza mental y su rechazo a los juegos psicológicos del Guasón.
#
# ---
# Thank you for using HeyDataAPI through Kronika!

# %% [markdown]
# # Response in Bionic Reading Markdown (optional):

# %%
#Placeholder. Will create the module and include it in the main notebook.
